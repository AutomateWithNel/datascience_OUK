# %% [markdown]
# # Python First Project

# %%
import numpy as np

# %%
array1 = np.array([1, 2, 3, 4, 5])
array1[1:]
# Out:
# array([2, 3, 4, 5])

# %%
Nel_Array = np.array([[1, 2, 3, 4, 5],[23,10,15,16,20]])
Nel_Array[1,0:3]
# Out:
# array([23, 10, 15])

# %%
Name = np.eye(2)
Name
# Out:
# array([[1., 0.],
#        [0., 1.]])

# %%
hey = np.zeros((3,3))
hey
# Out:
# array([[0., 0., 0.],
#        [0., 0., 0.],
#        [0., 0., 0.]])
